# %% [markdown]
# import the data

# %%
import pandas as pd

# %%
df = pd.read_csv("result.csv", delimiter=",")
df
# Out:
#       episode   step    reward  info     timestamp     obs_0     obs_1  \
# 0         0.0    0.0 -1.389655   0.0  1.679650e+09  0.013682  0.013316
# 1         0.0    1.0 -1.513281   0.0  1.679650e+09  0.043853  0.042083
# 2         0.0    2.0 -1.559966   0.0  1.679650e+09  0.084186  0.080007
# 3         0.0    3.0 -1.557379   0.0  1.679650e+09  0.130438  0.123797
# 4         0.0    4.0 -1.514907   0.0  1.679650e+09  0.179715  0.170944
# ...       ...    ...       ...   ...           ...       ...       ...
# 1995      9.0  195.0  1.643387   0.0  1.679650e+09  0.016023 -0.021945
# 1996      9.0  196.0  1.642209   0.0  1.679650e+09  0.011088 -0.025304
# 1997      9.0  197.0  1.642716   0.0  1.679650e+09  0.007984 -0.027461
# 1998      9.0  198.0  1.634751   0.0  1.679650e+09  0.004195 -0.029033
# 1999      9.0  199.0  1.639940   0.0  1.679650e+09 -0.001276 -0.030896
#
#          obs_2     obs_3     obs_4  ...   obs_309   obs_310   obs_311  \
# 0    -0.021371 -0.029317  0.001221  ...  0.009389 -0.535267 -0.001717
# 1    -0.056912 -0.077301  0.003332  ...  0.025483 -0.528323 -0.002555
# 2    -0.089216 -0.121493 -0.008056  ...  0.031378 -0.530603 -0.002908
# 3    -0.110976 -0.150377 -0.028199  ...  0.021509 -0.546160 -0.000571
# 4    -0.118389 -0.157974 -0.052214  ... -0.005936 -0.575679  0.005210
# ...        ...       ...       ...  ...       ...       ...       ...
# 1995 -0.223133 -0.128909 -0.091112  ...  0.092495 -0.322932 -0.032672
# 1996 -0.222518 -0.133515 -0.092572  ...  0.099743 -0.319556 -0.033837
# 1997 -0.222570 -0.145634 -0.094361  ...  0.112104 -0.318070 -0.036716
# 1998 -0.222018 -0.171272 -0.096102  ...  0.133622 -0.317409 -0.042347
# 1999 -0.217826 -0.178758 -0.096755  ...  0.151027 -0.319419 -0.045754
#
#        obs_312   obs_313   obs_314   obs_315   obs_316   obs_317   obs_318
# 0     0.844681  0.844631 -0.012196  0.535210  0.009383  0.999924  0.007979
# 1     0.849039  0.848661 -0.031585  0.527993  0.025468  0.999498  0.018856
# 2     0.847615  0.847040 -0.038816  0.530110  0.031360  0.999242  0.023059
# 3     0.837681  0.837405 -0.026035  0.545963  0.021497  0.999661  0.014698
# 4     0.817660  0.817655  0.010918  0.575606 -0.005928  0.999927 -0.010545
# ...        ...       ...       ...       ...       ...       ...       ...
# 1995  0.945858  0.941897 -0.108712  0.317824  0.092442  0.993536  0.065880
# 1996  0.946963  0.942309 -0.116484  0.313823  0.099688  0.992616  0.069108
# 1997  0.947356  0.941423 -0.130324  0.311027  0.112044  0.990791  0.076017
# 1998  0.947343  0.938837 -0.154726  0.307643  0.133551  0.987049  0.088868
# 1999  0.946508  0.935514 -0.174333  0.307282  0.150948  0.983623  0.098489
#
# [2000 rows x 324 columns]

# %% [markdown]
# build the network

# %% [markdown]
# https://machinelearningmastery.com/develop-your-first-neural-network-with-pytorch-step-by-step/

# %%
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
import math
from sklearn.metrics import mean_squared_error

# %%
X = pd.concat([df.iloc[:,4:49],df.iloc[:,50:]],axis=1,ignore_index=True)
y = df.iloc[:,49]

# %%
X = torch.tensor(X.values.astype(np.float32), requires_grad=True)
y = torch.tensor(y, dtype=torch.float32).reshape(-1, 1)

# %%
X.shape
# Out:
# torch.Size([2000, 319])

# %%
y.shape
# Out:
# torch.Size([2000, 1])

# %%
model = nn.Sequential(
    nn.Linear(8, 12),
    nn.ReLU(),
    nn.Linear(12, 8),
    nn.ReLU(),
    nn.Linear(8, 1),
    nn.Sigmoid())

# %%
class PimaClassifier(nn.Module):
    def __init__(self):
        super().__init__()
        self.hidden1 = nn.Linear(319, 160)
        self.act1 = nn.ReLU()
        self.hidden2 = nn.Linear(160, 80)
        self.act2 = nn.ReLU()
        self.output = nn.Linear(80, 16)
        self.act_output =  nn.Linear(16, 1)
 
    def forward(self, x):
        x = self.act1(self.hidden1(x))
        x = self.act2(self.hidden2(x))
        x = self.act_output(self.output(x))
        return x
 
model = PimaClassifier()
print(model)
# Out:
# PimaClassifier(
#   (hidden1): Linear(in_features=319, out_features=160, bias=True)
#   (act1): ReLU()
#   (hidden2): Linear(in_features=160, out_features=80, bias=True)
#   (act2): ReLU()
#   (output): Linear(in_features=80, out_features=16, bias=True)
#   (act_output): Linear(in_features=16, out_features=1, bias=True)
# )

# %%
y
# Out:
# tensor([[0.1378],
#         [0.1378],
#         [0.1378],
#         ...,
#         [0.1987],
#         [0.1987],
#         [0.1987]])

# %%
loss_fn = nn.MSELoss()  # binary cross entropy
optimizer = optim.Adam(model.parameters(), lr=0.001)

n_epochs = 100
batch_size = 10

for epoch in range(n_epochs):
    for i in range(0, len(X), batch_size):
        Xbatch = X[i:i+batch_size]
        y_pred = model(Xbatch)
        ybatch = y[i:i+batch_size]
        loss = loss_fn(y_pred, ybatch)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
    print(f'Finished epoch {epoch}, latest loss {loss}')
# Out:
# Finished epoch 0, latest loss 8020.09130859375
# Finished epoch 1, latest loss 0.002468616934493184
# Finished epoch 2, latest loss 0.016922561451792717
# Finished epoch 3, latest loss 0.06257106363773346
# Finished epoch 4, latest loss 0.014913161285221577
# Finished epoch 5, latest loss 0.014913161285221577
# Finished epoch 6, latest loss 0.1255146861076355
# Finished epoch 7, latest loss 0.04002407565712929
# Finished epoch 8, latest loss 0.07295076549053192
# Finished epoch 9, latest loss 0.33813220262527466
# Finished epoch 10, latest loss 0.031542859971523285
# Finished epoch 11, latest loss 0.11246015876531601
# Finished epoch 12, latest loss 2.6590938568115234
# Finished epoch 13, latest loss 0.9333924055099487
# Finished epoch 14, latest loss 11551.892578125
# Finished epoch 15, latest loss 0.1252184957265854
# Finished epoch 16, latest loss 3.6919007301330566
# Finished epoch 17, latest loss 0.23499147593975067
# Finished epoch 18, latest loss 0.03983744978904724
# Finished epoch 19, latest loss 4783.08203125
# Finished epoch 20, latest loss 0.0034597800113260746
# Finished epoch 21, latest loss 0.0011171023361384869
# Finished epoch 22, latest loss 0.0007045377278700471
# Finished epoch 23, latest loss 0.014032388105988503
# Finished epoch 24, latest loss 0.0013694907538592815
# Finished epoch 25, latest loss 0.005761794745922089
# Finished epoch 26, latest loss 0.05479491874575615
# Finished epoch 27, latest loss 0.051396291702985764
# Finished epoch 28, latest loss 0.0005454339552670717
# Finished epoch 29, latest loss 0.0012103868648409843
# Finished epoch 30, latest loss 4.408081531524658
# Finished epoch 31, latest loss 0.0009596474701538682
# Finished epoch 32, latest loss 0.08996692299842834
# Finished epoch 33, latest loss 0.10946333408355713
# Finished epoch 34, latest loss 0.00016907803365029395
# Finished epoch 35, latest loss 19488312.0
# Finished epoch 36, latest loss 12.883526802062988
# Finished epoch 37, latest loss 7.232060432434082
# Finished epoch 38, latest loss 0.1415831297636032
# Finished epoch 39, latest loss 4168299008.0
# Finished epoch 40, latest loss 0.5288110375404358
# Finished epoch 41, latest loss 0.001178720616735518
# Finished epoch 42, latest loss 0.0011988028418272734
# Finished epoch 43, latest loss 0.001260393182747066
# Finished epoch 44, latest loss 0.0013453164137899876
# Finished epoch 45, latest loss 0.002075925935059786
# Finished epoch 46, latest loss 0.0018094271654263139
# Finished epoch 47, latest loss 0.0004308489733375609
# Finished epoch 48, latest loss 5.8829587942454964e-05
# Finished epoch 49, latest loss 1.5648931366740726e-05
# Finished epoch 50, latest loss 0.0005109140765853226
# Finished epoch 51, latest loss 0.0010477553587406874
# Finished epoch 52, latest loss 0.001424318295903504
# Finished epoch 53, latest loss 0.0016304496675729752
# Finished epoch 54, latest loss 0.001991414465010166
# Finished epoch 55, latest loss 0.001706471899524331
# Finished epoch 56, latest loss 0.0006796947563998401
# Finished epoch 57, latest loss 5.434716149466112e-05
# Finished epoch 58, latest loss 3.7247700674925e-05
# Finished epoch 59, latest loss 1.7508105543129204e-07
# Finished epoch 60, latest loss 0.00016482397040817887
# Finished epoch 61, latest loss 1.148137562267948e-05
# Finished epoch 62, latest loss 1.5361462146756821e-06
# Finished epoch 63, latest loss 0.00025820889277383685
# Finished epoch 64, latest loss 0.00025820935843512416
# Finished epoch 65, latest loss 0.00023675954435020685
# Finished epoch 66, latest loss 0.00033217453164979815
# Finished epoch 67, latest loss 0.0005113999941386282
# Finished epoch 68, latest loss 0.00025346747133880854
# Finished epoch 69, latest loss 0.0013159402878955007
# Finished epoch 70, latest loss 0.0015380335971713066
# Finished epoch 71, latest loss 0.0002396344643784687
# Finished epoch 72, latest loss 0.00018820571131072938
# Finished epoch 73, latest loss 3.038011163880583e-05
# Finished epoch 74, latest loss 0.000565608381293714
# Finished epoch 75, latest loss 6.943934067749069e-07
# Finished epoch 76, latest loss 0.00010577256034594029
# Finished epoch 77, latest loss 9.258905629394576e-05
# Finished epoch 78, latest loss 0.001521972008049488
# Finished epoch 79, latest loss 0.0010796551359817386
# Finished epoch 80, latest loss 0.0001357085711788386
# Finished epoch 81, latest loss 0.00021339862723834813
# Finished epoch 82, latest loss 0.0006826195167377591
# Finished epoch 83, latest loss 0.0030171722173690796
# Finished epoch 84, latest loss 0.0003496131976135075
# Finished epoch 85, latest loss 3.2758284760348033e-06
# Finished epoch 86, latest loss 0.000515712657943368
# Finished epoch 87, latest loss 0.004072508774697781
# Finished epoch 88, latest loss 0.002129489555954933
# Finished epoch 89, latest loss 0.00039900309639051557
# Finished epoch 90, latest loss 0.0040726992301642895
# Finished epoch 91, latest loss 6.0374361055437475e-05
# Finished epoch 92, latest loss 0.0024559530429542065
# Finished epoch 93, latest loss 3.2676700357114896e-05
# Finished epoch 94, latest loss 0.009738428518176079
# Finished epoch 95, latest loss 1120.5079345703125
# Finished epoch 96, latest loss 0.001329439808614552
# Finished epoch 97, latest loss 0.00037441551103256643
# Finished epoch 98, latest loss 0.003709182608872652
# Finished epoch 99, latest loss 0.14935220777988434

# %%
# compute accuracy (no_grad is optional)
with torch.no_grad():
    y_pred = model(X)
 
trainScore = math.sqrt(mean_squared_error(y_pred,y))
print('Train Score: %.2f RMSE' % (trainScore))
# Out:
# Train Score: 0.46 RMSE
