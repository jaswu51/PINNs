# %% [markdown]
# # import the data

# %% [markdown]
# $$
# f=x^2 + \sqrt {y} + z
# $$

# %%
import pandas as pd

# %%
df = pd.read_csv("data/result_testdata.csv", delimiter=",")
df
# Out:
#             x         y         z         f
# 0    0.876300  0.087160  0.678294  1.741426
# 1    0.506543  0.427771  0.117943  1.028571
# 2    0.469181  0.208947  0.862431  1.539668
# 3    0.997632  0.038999  0.628393  1.821145
# 4    0.680144  0.432733  0.571025  1.691445
# ..        ...       ...       ...       ...
# 569  0.213704  0.183989  0.577722  1.052330
# 570  0.727660  0.021602  0.820556  1.497021
# 571  0.452470  0.848223  0.896740  2.022459
# 572  0.470553  0.443268  0.204643  1.091847
# 573  0.354489  0.567065  0.781405  1.660105
#
# [574 rows x 4 columns]

# %% [markdown]
# # build the network

# %% [markdown]
# https://machinelearningmastery.com/develop-your-first-neural-network-with-pytorch-step-by-step/

# %%
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from torch import autograd
import math
from sklearn.metrics import mean_squared_error

# %%
X = df.iloc[:,:3]
y = df.iloc[:,3]
# y = df.iloc[:,:3].sum(axis=1)

# %%
X = torch.tensor(X.values.astype(np.float32), requires_grad=True)
y = torch.tensor(y, dtype=torch.float32).reshape(-1, 1)

# %%
X.shape
# Out:
# torch.Size([574, 3])

# %%
y.shape
# Out:
# torch.Size([574, 1])

# %%
class EstimateF(nn.Module):
    def __init__(self):
        super().__init__()
        self.hidden1 = nn.Linear(3, 160)
        self.act1 = nn.ReLU()
        self.hidden2 = nn.Linear(160, 80)
        self.act2 = nn.ReLU()
        self.output = nn.Linear(80, 16)
        self.act_output =  nn.Linear(16, 1)
 
    def forward(self, x):
        x = self.act1(self.hidden1(x))
        x = self.act2(self.hidden2(x))
        x = self.act_output(self.output(x))
        return x
 
model = EstimateF()
print(model)
# Out:
# EstimateF(
#   (hidden1): Linear(in_features=3, out_features=160, bias=True)
#   (act1): ReLU()
#   (hidden2): Linear(in_features=160, out_features=80, bias=True)
#   (act2): ReLU()
#   (output): Linear(in_features=80, out_features=16, bias=True)
#   (act_output): Linear(in_features=16, out_features=1, bias=True)
# )

# %%
loss_fn = nn.MSELoss()  
optimizer = optim.Adam(model.parameters(), lr=0.001)

n_epochs = 500
batch_size = 10

for epoch in range(n_epochs):
    for i in range(0, len(X), batch_size):
        Xbatch = X[i:i+batch_size].clone()
        # Xbatch.requires_grad=True
        y_pred = model(Xbatch)
        ybatch = y[i:i+batch_size]
        f_x_t = autograd.grad(y_pred,Xbatch,torch.ones([Xbatch.shape[0], 1]), retain_graph=True, create_graph=True)[0] #first derivative
        loss = loss_fn(y_pred, ybatch)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
    print(f'Finished epoch {epoch}, latest loss {loss}')
# Out:
# Finished epoch 0, latest loss 0.02473844774067402
# Finished epoch 1, latest loss 0.0057207141071558
# Finished epoch 2, latest loss 0.004246027674525976
# Finished epoch 3, latest loss 0.003259702818468213
# Finished epoch 4, latest loss 0.0018020868301391602
# Finished epoch 5, latest loss 0.0007793891127221286
# Finished epoch 6, latest loss 0.0006032128585502505
# Finished epoch 7, latest loss 0.00047667903709225357
# Finished epoch 8, latest loss 0.0003582267672754824
# Finished epoch 9, latest loss 0.0002847350260708481
# Finished epoch 10, latest loss 0.00025659165112301707
# Finished epoch 11, latest loss 0.00021872295474167913
# Finished epoch 12, latest loss 0.00019418285228312016
# Finished epoch 13, latest loss 0.00016890194092411548
# Finished epoch 14, latest loss 0.00015878220438025892
# Finished epoch 15, latest loss 0.0001374365238007158
# Finished epoch 16, latest loss 0.0001221296115545556
# Finished epoch 17, latest loss 0.00011349030683049932
# Finished epoch 18, latest loss 9.946194768417627e-05
# Finished epoch 19, latest loss 9.838567348197103e-05
# Finished epoch 20, latest loss 8.469015301670879e-05
# Finished epoch 21, latest loss 9.191174467559904e-05
# Finished epoch 22, latest loss 9.365206642542034e-05
# Finished epoch 23, latest loss 9.574333671480417e-05
# Finished epoch 24, latest loss 0.00010232735075987875
# Finished epoch 25, latest loss 0.00010750136425485834
# Finished epoch 26, latest loss 0.00010797926370287314
# Finished epoch 27, latest loss 0.0001066494733095169
# Finished epoch 28, latest loss 0.00010355578706366941
# Finished epoch 29, latest loss 9.98937975964509e-05
# Finished epoch 30, latest loss 8.968571637524292e-05
# Finished epoch 31, latest loss 8.402612002100796e-05
# Finished epoch 32, latest loss 7.736813131486997e-05
# Finished epoch 33, latest loss 7.336067210417241e-05
# Finished epoch 34, latest loss 6.712503090966493e-05
# Finished epoch 35, latest loss 5.878018055227585e-05
# Finished epoch 36, latest loss 6.024850154062733e-05
# Finished epoch 37, latest loss 6.01670217292849e-05
# Finished epoch 38, latest loss 5.731392229790799e-05
# Finished epoch 39, latest loss 5.385751137509942e-05
# Finished epoch 40, latest loss 5.155513281351887e-05
# Finished epoch 41, latest loss 4.9173668230650946e-05
# Finished epoch 42, latest loss 4.906360118184239e-05
# Finished epoch 43, latest loss 5.0117698265239596e-05
# Finished epoch 44, latest loss 5.346675970940851e-05
# Finished epoch 45, latest loss 5.910006439080462e-05
# Finished epoch 46, latest loss 6.560962356161326e-05
# Finished epoch 47, latest loss 6.85899140080437e-05
# Finished epoch 48, latest loss 7.25416248315014e-05
# Finished epoch 49, latest loss 7.583921251352876e-05
# Finished epoch 50, latest loss 7.556097261840478e-05
# Finished epoch 51, latest loss 7.415381696773693e-05
# Finished epoch 52, latest loss 7.127040589693934e-05
# Finished epoch 53, latest loss 6.9702226028312e-05
# Finished epoch 54, latest loss 6.449010834330693e-05
# Finished epoch 55, latest loss 5.9591897297650576e-05
# Finished epoch 56, latest loss 5.433695696410723e-05
# Finished epoch 57, latest loss 4.442953286343254e-05
# Finished epoch 58, latest loss 3.9291502616833895e-05
# Finished epoch 59, latest loss 3.4997759939869866e-05
# Finished epoch 60, latest loss 3.85572093364317e-05
# Finished epoch 61, latest loss 8.245189383160323e-05
# Finished epoch 62, latest loss 0.0001134358171839267
# Finished epoch 63, latest loss 7.268698391271755e-05
# Finished epoch 64, latest loss 9.938707808032632e-05
# Finished epoch 65, latest loss 0.0004966635024175048
# Finished epoch 66, latest loss 0.0002784697280731052
# Finished epoch 67, latest loss 9.362668060930446e-05
# Finished epoch 68, latest loss 4.883729707216844e-05
# Finished epoch 69, latest loss 3.6855384678347036e-05
# Finished epoch 70, latest loss 3.169977571815252e-05
# Finished epoch 71, latest loss 2.9649874704773538e-05
# Finished epoch 72, latest loss 2.560547181928996e-05
# Finished epoch 73, latest loss 2.0125833543716e-05
# Finished epoch 74, latest loss 1.8906981495092623e-05
# Finished epoch 75, latest loss 2.0278275769669563e-05
# Finished epoch 76, latest loss 3.2347288652090356e-05
# Finished epoch 77, latest loss 3.996371742687188e-05
# Finished epoch 78, latest loss 6.0640828451141715e-05
# Finished epoch 79, latest loss 6.95216003805399e-05
# Finished epoch 80, latest loss 7.597997318953276e-05
# Finished epoch 81, latest loss 8.269235695479438e-05
# Finished epoch 82, latest loss 0.00010031124111264944
# Finished epoch 83, latest loss 9.640616190154105e-05
# Finished epoch 84, latest loss 9.94271831586957e-05
# Finished epoch 85, latest loss 9.54935239860788e-05
# Finished epoch 86, latest loss 9.29417583392933e-05
# Finished epoch 87, latest loss 8.239744056481868e-05
# Finished epoch 212, latest loss 1.0002361705119256e-05
# Finished epoch 213, latest loss 1.2846599020122085e-05
# Finished epoch 214, latest loss 8.76278500072658e-06
# Finished epoch 215, latest loss 7.088263373589143e-06
# Finished epoch 216, latest loss 1.4611429833166767e-05
# Finished epoch 217, latest loss 3.35813092533499e-06
# Finished epoch 218, latest loss 1.1267522495472804e-05
# Finished epoch 219, latest loss 8.973013791546691e-06
# Finished epoch 220, latest loss 4.901433931081556e-05
# Finished epoch 221, latest loss 1.6019550457713194e-05
# Finished epoch 222, latest loss 0.00033695748425088823
# Finished epoch 223, latest loss 0.00010887491225730628
# Finished epoch 224, latest loss 6.696688069496304e-05
# Finished epoch 225, latest loss 0.00013063100050203502
# Finished epoch 226, latest loss 7.798939623171464e-05
# Finished epoch 227, latest loss 5.9522822994040325e-05
# Finished epoch 228, latest loss 7.23311968613416e-05
# Finished epoch 229, latest loss 7.307476334972307e-05
# Finished epoch 230, latest loss 5.855368362972513e-05
# Finished epoch 231, latest loss 4.768162762047723e-05
# Finished epoch 232, latest loss 5.3277264669304714e-05
# Finished epoch 233, latest loss 0.0006765209836885333
# Finished epoch 234, latest loss 0.0007267801556736231
# Finished epoch 235, latest loss 0.00044755719136446714
# Finished epoch 236, latest loss 0.00041321286698803306
# Finished epoch 237, latest loss 0.00045132305240258574
# Finished epoch 238, latest loss 0.0004968292196281254
# Finished epoch 239, latest loss 0.0003841812431346625
# Finished epoch 240, latest loss 0.0001590218162164092
# Finished epoch 241, latest loss 4.1136696381727234e-05
# Finished epoch 242, latest loss 1.5550549505860545e-05
# Finished epoch 243, latest loss 3.413542435737327e-05
# Finished epoch 244, latest loss 1.8531505702412687e-05
# Finished epoch 245, latest loss 1.1188171811227221e-05
# Finished epoch 246, latest loss 1.1992418876616284e-05
# Finished epoch 247, latest loss 1.4816189832345117e-05
# Finished epoch 248, latest loss 1.8604754586704075e-05
# Finished epoch 249, latest loss 2.3771257474436425e-05
# Finished epoch 250, latest loss 3.0070175853325054e-05
# Finished epoch 251, latest loss 3.761164771276526e-05
# Finished epoch 252, latest loss 4.410414840094745e-05
# Finished epoch 253, latest loss 5.4856398492120206e-05
# Finished epoch 254, latest loss 6.027470590197481e-05
# Finished epoch 255, latest loss 6.264648254727945e-05
# Finished epoch 256, latest loss 6.291601312113926e-05
# Finished epoch 257, latest loss 5.89223054703325e-05
# Finished epoch 258, latest loss 6.0297479649307206e-05
# Finished epoch 259, latest loss 5.711344056180678e-05
# Finished epoch 260, latest loss 5.325138408807106e-05
# Finished epoch 261, latest loss 5.188037903280929e-05
# Finished epoch 262, latest loss 4.11011787946336e-05
# Finished epoch 263, latest loss 3.195417230017483e-05
# Finished epoch 264, latest loss 2.8327329346211627e-05
# Finished epoch 265, latest loss 3.06267938867677e-05
# Finished epoch 266, latest loss 4.5915534428786486e-05
# Finished epoch 267, latest loss 7.105461554601789e-05
# Finished epoch 268, latest loss 6.672160816378891e-05
# Finished epoch 269, latest loss 7.237894169520587e-05
# Finished epoch 270, latest loss 0.000765291799325496
# Finished epoch 271, latest loss 0.00023419453646056354
# Finished epoch 272, latest loss 0.0002897626254707575
# Finished epoch 273, latest loss 0.00021606488735415041
# Finished epoch 274, latest loss 9.458818385610357e-05
# Finished epoch 275, latest loss 6.783590652048588e-05
# Finished epoch 276, latest loss 2.675217365322169e-05
# Finished epoch 277, latest loss 2.3407641492667608e-05
# Finished epoch 278, latest loss 2.047266207227949e-05
# Finished epoch 279, latest loss 1.961446469067596e-05
# Finished epoch 280, latest loss 2.4119835870806128e-05
# Finished epoch 281, latest loss 2.045670225925278e-05
# Finished epoch 282, latest loss 1.776841963874176e-05
# Finished epoch 283, latest loss 1.181521929538576e-05
# Finished epoch 284, latest loss 5.51337689103093e-06
# Finished epoch 285, latest loss 1.6897909517865628e-05
# Finished epoch 286, latest loss 4.2456857045181096e-05
# Finished epoch 287, latest loss 3.7580233765766025e-05
# Finished epoch 288, latest loss 0.00039570964872837067
# Finished epoch 289, latest loss 0.000667925167363137
# Finished epoch 290, latest loss 5.5353382776957005e-05
# Finished epoch 291, latest loss 8.564202289562672e-05
# Finished epoch 292, latest loss 4.75130436825566e-05
# Finished epoch 293, latest loss 4.3885462218895555e-05
# Finished epoch 294, latest loss 4.5942080760141835e-05
# Finished epoch 295, latest loss 4.5215569116408005e-05
# Finished epoch 296, latest loss 4.287683259462938e-05
# Finished epoch 297, latest loss 4.231902858009562e-05
# Finished epoch 298, latest loss 4.0491380786988884e-05
# Finished epoch 299, latest loss 3.180581552442163e-05
# Finished epoch 300, latest loss 1.6803558537503704e-05
# Finished epoch 301, latest loss 9.727336873766035e-06
# Finished epoch 302, latest loss 4.034422090626322e-06
# Finished epoch 303, latest loss 5.051984771853313e-06
# Finished epoch 304, latest loss 2.993711859744508e-06
# Finished epoch 305, latest loss 3.5479774851410184e-06
# Finished epoch 306, latest loss 2.8960500912944553e-06
# Finished epoch 307, latest loss 1.5170101050898666e-06
# Finished epoch 308, latest loss 2.8855763503088383e-06
# Finished epoch 309, latest loss 1.7667116480879486e-06
# Finished epoch 310, latest loss 1.7571524040249642e-06
# Finished epoch 311, latest loss 1.4763248827875941e-06
# Finished epoch 312, latest loss 1.7815476667237817e-06
# Finished epoch 313, latest loss 2.142597622878384e-06
# Finished epoch 314, latest loss 4.679202447732678e-06
# Finished epoch 315, latest loss 3.1149452297540847e-06
# Finished epoch 316, latest loss 4.200468993076356e-06
# Finished epoch 317, latest loss 3.916145487892209e-06
# Finished epoch 318, latest loss 2.6292332222510595e-06
# Finished epoch 319, latest loss 2.7020989818993257e-06
# Finished epoch 320, latest loss 4.630509920389159e-06
# Finished epoch 321, latest loss 6.243963525776053e-06
# Finished epoch 322, latest loss 6.925370144017506e-06
# Finished epoch 323, latest loss 7.0868045440875e-05
# Finished epoch 324, latest loss 0.00028446383657865226
# Finished epoch 325, latest loss 7.017476309556514e-05
# Finished epoch 326, latest loss 2.290510201419238e-05
# Finished epoch 327, latest loss 8.431265996478032e-06
# Finished epoch 328, latest loss 1.5264184185070917e-05
# Finished epoch 329, latest loss 1.4983104847487994e-05
# Finished epoch 330, latest loss 7.026394541753689e-06
# Finished epoch 331, latest loss 7.094649390637642e-06
# Finished epoch 332, latest loss 6.586987183254678e-06
# Finished epoch 333, latest loss 6.7621326707012486e-06
# Finished epoch 334, latest loss 5.270228939480148e-06
# Finished epoch 335, latest loss 4.111422640562523e-06
# Finished epoch 336, latest loss 3.0242576940509025e-06
# Finished epoch 337, latest loss 2.9035927582299337e-06
# Finished epoch 338, latest loss 3.1872259569354355e-06
# Finished epoch 339, latest loss 2.4929154278652277e-06
# Finished epoch 340, latest loss 2.7058317755290773e-06
# Finished epoch 341, latest loss 3.303809307908523e-06
# Finished epoch 342, latest loss 3.935605491278693e-06
# Finished epoch 343, latest loss 3.363590167282382e-06
# Finished epoch 344, latest loss 7.6229566730035e-06
# Finished epoch 345, latest loss 1.8361990441917442e-05
# Finished epoch 346, latest loss 3.2477506465511397e-05
# Finished epoch 347, latest loss 4.413233182276599e-05
# Finished epoch 348, latest loss 7.29566381778568e-05
# Finished epoch 349, latest loss 9.441495058126748e-05
# Finished epoch 350, latest loss 2.5220915631507523e-05
# Finished epoch 351, latest loss 3.576573362806812e-05
# Finished epoch 352, latest loss 2.3944277927512303e-05
# Finished epoch 353, latest loss 3.0422908821492456e-05
# Finished epoch 354, latest loss 3.116588413831778e-05
# Finished epoch 355, latest loss 3.8356654840754345e-05
# Finished epoch 356, latest loss 3.7426772905746475e-05
# Finished epoch 357, latest loss 3.998089232482016e-05
# Finished epoch 358, latest loss 4.087819979758933e-05
# Finished epoch 359, latest loss 5.6383010814897716e-05
# Finished epoch 360, latest loss 7.0419795520138e-05
# Finished epoch 361, latest loss 0.00010349202057113871
# Finished epoch 362, latest loss 0.0001795826683519408
# Finished epoch 363, latest loss 0.0005312138819135725
# Finished epoch 364, latest loss 0.000486306642415002
# Finished epoch 365, latest loss 0.0004780323361046612
# Finished epoch 366, latest loss 0.0002179528382839635
# Finished epoch 367, latest loss 3.352779458509758e-05
# Finished epoch 368, latest loss 2.530925667088013e-05
# Finished epoch 369, latest loss 2.971230242110323e-05
# Finished epoch 370, latest loss 3.268163709435612e-05
# Finished epoch 371, latest loss 3.80515048163943e-05
# Finished epoch 372, latest loss 4.417225864017382e-05
# Finished epoch 373, latest loss 4.715919203590602e-05
# Finished epoch 374, latest loss 4.878852632828057e-05
# Finished epoch 375, latest loss 4.794184860656969e-05
# Finished epoch 376, latest loss 4.5237658923724666e-05
# Finished epoch 377, latest loss 4.782844553119503e-05
# Finished epoch 378, latest loss 5.080008850200102e-05
# Finished epoch 379, latest loss 5.2958446758566424e-05
# Finished epoch 380, latest loss 5.52750971110072e-05
# Finished epoch 381, latest loss 5.187869828660041e-05
# Finished epoch 382, latest loss 5.531440910999663e-05
# Finished epoch 383, latest loss 4.72752726636827e-05
# Finished epoch 384, latest loss 3.7922342016827315e-05
# Finished epoch 385, latest loss 2.980429053422995e-05
# Finished epoch 386, latest loss 1.6140596926561557e-05
# Finished epoch 387, latest loss 3.387442120583728e-06
# Finished epoch 388, latest loss 4.652458756027045e-06
# Finished epoch 389, latest loss 2.237840999441687e-05
# Finished epoch 390, latest loss 5.518548277905211e-05
# Finished epoch 391, latest loss 7.591663597850129e-05
# Finished epoch 392, latest loss 2.9282633477123454e-05
# Finished epoch 393, latest loss 0.0007646692683920264
# Finished epoch 394, latest loss 0.00015721817908342928
# Finished epoch 395, latest loss 7.642662239959463e-05
# Finished epoch 396, latest loss 6.969303649384528e-05
# Finished epoch 397, latest loss 6.14105592831038e-05
# Finished epoch 398, latest loss 6.62932507111691e-05
# Finished epoch 399, latest loss 6.507553916890174e-05
# Finished epoch 400, latest loss 6.55461844871752e-05
# Finished epoch 401, latest loss 6.667632260359824e-05
# Finished epoch 402, latest loss 6.307302101049572e-05
# Finished epoch 403, latest loss 5.6566568673588336e-05
# Finished epoch 404, latest loss 5.39147513336502e-05
# Finished epoch 405, latest loss 4.2884203139692545e-05
# Finished epoch 406, latest loss 3.208074122085236e-05
# Finished epoch 407, latest loss 2.5409957743249834e-05
# Finished epoch 408, latest loss 1.560436430736445e-05
# Finished epoch 409, latest loss 1.3493526239471976e-05
# Finished epoch 410, latest loss 9.25885160540929e-06
# Finished epoch 411, latest loss 8.385925866605248e-06
# Finished epoch 412, latest loss 5.931258328928379e-06
# Finished epoch 413, latest loss 4.2328147173975594e-06
# Finished epoch 414, latest loss 3.046570554943173e-06
# Finished epoch 415, latest loss 1.861063879005087e-06
# Finished epoch 416, latest loss 1.2639643500733655e-06
# Finished epoch 417, latest loss 1.0767307685455307e-06
# Finished epoch 418, latest loss 6.777943326596869e-07
# Finished epoch 419, latest loss 5.89300498177181e-07
# Finished epoch 420, latest loss 1.3757821761828382e-06
# Finished epoch 421, latest loss 5.37892219654168e-07
# Finished epoch 422, latest loss 7.553236969215504e-07
# Finished epoch 423, latest loss 6.78510616580752e-07
# Finished epoch 424, latest loss 1.9365688785910606e-06
# Finished epoch 425, latest loss 5.269023859000299e-06
# Finished epoch 426, latest loss 1.0741387086454779e-05
# Finished epoch 427, latest loss 6.13624433754012e-05
# Finished epoch 428, latest loss 0.00013593328185379505
# Finished epoch 429, latest loss 0.00014740311598870903
# Finished epoch 430, latest loss 2.8429167286958545e-05
# Finished epoch 431, latest loss 4.092687049706001e-06
# Finished epoch 432, latest loss 2.3555576262879185e-05
# Finished epoch 433, latest loss 2.3865370167186484e-05
# Finished epoch 434, latest loss 3.612782893469557e-05
# Finished epoch 435, latest loss 3.7896548747085035e-05
# Finished epoch 436, latest loss 6.884369940962642e-05
# Finished epoch 437, latest loss 0.00010398784070275724
# Finished epoch 438, latest loss 0.00014919252134859562
# Finished epoch 439, latest loss 0.0006438699783757329
# Finished epoch 440, latest loss 0.00022014568094164133
# Finished epoch 441, latest loss 0.00044496962800621986
# Finished epoch 442, latest loss 0.0001942097005667165
# Finished epoch 443, latest loss 1.5503866961807944e-05
# Finished epoch 444, latest loss 8.642839020467363e-06
# Finished epoch 445, latest loss 8.544244337826967e-06
# Finished epoch 446, latest loss 9.035170478455257e-06
# Finished epoch 447, latest loss 9.375082299811766e-06
# Finished epoch 448, latest loss 9.90393164101988e-06
# Finished epoch 449, latest loss 1.0272902727592736e-05
# Finished epoch 450, latest loss 1.1231024473090656e-05
# Finished epoch 451, latest loss 1.1954194633290172e-05
# Finished epoch 452, latest loss 1.2892451195511967e-05
# Finished epoch 453, latest loss 1.4146869034448173e-05
# Finished epoch 454, latest loss 1.457752296118997e-05
# Finished epoch 455, latest loss 1.4988960174378008e-05
# Finished epoch 456, latest loss 1.5273575627361424e-05
# Finished epoch 457, latest loss 1.5937703210511245e-05
# Finished epoch 458, latest loss 1.7630847651162185e-05
# Finished epoch 459, latest loss 1.9757648260565475e-05
# Finished epoch 460, latest loss 2.3169021005742252e-05
# Finished epoch 461, latest loss 2.6874557079281658e-05
# Finished epoch 462, latest loss 2.8026966901961714e-05
# Finished epoch 463, latest loss 2.2800204533268698e-05
# Finished epoch 464, latest loss 1.3959154784970451e-05
# Finished epoch 465, latest loss 2.498793946870137e-06
# Finished epoch 466, latest loss 1.59045412146952e-05
# Finished epoch 467, latest loss 6.839250272605568e-05
# Finished epoch 468, latest loss 0.0001340671442449093
# Finished epoch 469, latest loss 7.347625069087371e-05
# Finished epoch 470, latest loss 0.00047327610081993043
# Finished epoch 471, latest loss 5.6480821513105184e-05
# Finished epoch 472, latest loss 5.109926132718101e-05
# Finished epoch 473, latest loss 5.441771645564586e-05
# Finished epoch 474, latest loss 3.486428613541648e-05
# Finished epoch 475, latest loss 3.1185150874080136e-05
# Finished epoch 476, latest loss 3.405801544431597e-05
# Finished epoch 477, latest loss 3.8791131373727694e-05
# Finished epoch 478, latest loss 4.807208460988477e-05
# Finished epoch 479, latest loss 4.953092138748616e-05
# Finished epoch 480, latest loss 4.6124972868710756e-05
# Finished epoch 481, latest loss 2.886185575334821e-05
# Finished epoch 482, latest loss 1.5863057342357934e-05
# Finished epoch 483, latest loss 7.29968041923712e-06
# Finished epoch 484, latest loss 4.5665815378015395e-06
# Finished epoch 485, latest loss 4.2915166886814404e-06
# Finished epoch 486, latest loss 4.016098046122352e-06
# Finished epoch 487, latest loss 4.121189704164863e-06
# Finished epoch 488, latest loss 5.241804046818288e-06
# Finished epoch 489, latest loss 4.407644155435264e-06
# Finished epoch 490, latest loss 4.773972250404768e-06
# Finished epoch 491, latest loss 3.67607708540163e-06
# Finished epoch 492, latest loss 3.699808530654991e-06
# Finished epoch 493, latest loss 3.1947561183187645e-06
# Finished epoch 494, latest loss 3.691654001158895e-06
# Finished epoch 495, latest loss 1.592522949067643e-06
# Finished epoch 496, latest loss 7.722941290921881e-07
# Finished epoch 497, latest loss 6.381668526955764e-07
# Finished epoch 498, latest loss 1.880702984635718e-05
# Finished epoch 499, latest loss 2.1939642465440556e-05

# %%
# compute accuracy (no_grad is optional)
# with torch.no_grad():
#     y_pred = model(X)

X.requires_grad_()
X.retain_grad()
y_pred = model(X)

trainScore = math.sqrt(mean_squared_error(y_pred.detach().numpy(),y.detach().numpy()))
print('Train Score: %.2f RMSE' % (trainScore))
# Out:
# Train Score: 0.00 RMSE

# %% [markdown]
# # test the auto gradient

# %% [markdown]
# $$
# f=x^2 + \sqrt {y} + z
# $$
#
# $$
# f_x'=2x
# $$
#
# $$
# f_y'=\frac{1}{2} * y ^ {-\frac{1}{2}}
# $$
#
# $$
# f_z'=1
# $$

# %%
X[0]
# Out:
# tensor([0.8763, 0.0872, 0.6783], grad_fn=<SelectBackward0>)

# %%
y[0]
# Out:
# tensor([1.7414])

# %%
model(X[0])
# Out:
# tensor([1.7396], grad_fn=<AddBackward0>)

# %%
autograd.grad(model(X),X,torch.ones([X.shape[0], 1]), retain_graph=True, create_graph=True)[0][0] #first derivative
# Out:
# tensor([1.6703, 1.6706, 1.0074], grad_fn=<SelectBackward0>)

# %% [markdown]
# good match!
